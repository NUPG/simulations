# %%
# %matplotlib inline

from pprint import pprint
from peer_review import *
from vancouver_simulations import *
import numpy as np
import matplotlib.pyplot as plt
import operator

# %%
plot_cdfs(num_truths=(5, 10, 15))
