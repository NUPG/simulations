# %%
import random
import math

# invert a dictionary of lists (assuming no duplicates)
def invert_dictlist(d):
    return dict( (v,k) for k in d for v in d[k] )

# invert a dictionary of lists (with duplicates)
def invert_dictlist_dup(d):
    values = set(a for b in d.values() for a in b)
    reverse_d = dict((new_key, [key for key,value in d.items() if new_key in value]) for new_key in values)
    return reverse_d

# %%
# assign students in groups to k submissions.
def peer_assignment(groups,k,debug=False):
    """Given no cover, first generate a cover with the first few submissions"""
    """Then, generate the rest of the assignments"""
    
    submissions = groups.keys()
    
    # lookup for which submissions to exclude from a particular student.
    exclude = invert_dictlist(groups)
    students = exclude.keys()
    studentList = list(students);

 
    # load = ceil(number of students * k / number of submissions)
    # this is how many copies of random submission lists we need.
    load = int(math.ceil((len(students) * k) / len(submissions)))
    
    # Repeat the submissions so that they each occur load times.
    repeatedSubmissions = [x for x in submissions for i in range(load-1)]
    
    # initialize empty assignment and cover
    assignments = {s : [] for s in students}
    cover = {s : [] for s in students}
    
    # cover with the first few submissions. Every time a submission is used, remove it.
    # This way, each submission is repeated at most load # of times.
    for s in students:
        for currentSubmission in repeatedSubmissions:
            if currentSubmission not in exclude[s]:
                assignments[s].append(currentSubmission);
                repeatedSubmissions.remove(currentSubmission);
                cover[s].append(currentSubmission);
                break;
    
    assignments = peer_assignment_with_cover(groups,k,cover);
    
    if (assignments == -1) and debug:
        print("Couldn't generate good cover!");
    
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
            
    if not(done) and debug:
        print("Not a good assignment!")
        return -1;
    
    return assignments;
    
def peer_assignment_with_cover_submissions(groups,k,coverSubmissions,debug=False):
    """Given a list of submissions, generate a cover using those submissions"""
    """Then, generate the rest of the assignments"""
    
    submissions = groups.keys()
    
    # lookup for which submissions to exclude from a particular student.
    exclude = invert_dictlist(groups)
    students = exclude.keys()
    studentList = list(students);

    # load = ceil(number of students * k / number of submissions)
    # this is how many copies of random submission lists we need.
    load = int(math.ceil((len(students) * k) / len(submissions)))
    
    repeatedCoverSubmissions = [x for x in coverSubmissions for i in range(load-1)]
    
    # initialize empty cover
    cover = {s : [] for s in students}
    
    # cover with the first few of coverSubmissions
    for s in students:
        for currentSubmission in repeatedCoverSubmissions:
            if currentSubmission not in exclude[s]:
                repeatedCoverSubmissions.remove(currentSubmission);
                cover[s].append(currentSubmission);
                break;
    
    for s in students:
        if len(assignments[s]) == 0:
            if (debug):
                print("Error: Submissions cannot cover students!")
            return -1;
        
    assignments = peer_assignment_with_cover(groups,k,cover);
    
    if (assignments == -1) and debug:
        print("Couldn't generate good cover!");
        return -1;
    
     
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
            
    if not(done) and debug:
        print("Not a good assignment!")
        return -1;
    
    return assignments;
    
def peer_assignment_with_cover(groups,k,cover,debug=False):
    """Given an entire cover of (student,submission) pairs, generate the rest of the assignments"""
    
    
    for i in range(10000):
        
        submissions = groups.keys()
        submissionsList = list(submissions);
        
        # lookup for which submissions to exclude from a particular student.
        exclude = invert_dictlist(groups)
        students = exclude.keys()
        studentList = list(students);
    
     
        # load = ceil(number of students * k / number of submissions)
        # this is how many copies of random submission lists we need.
        load = int(math.ceil((len(students) * k) / len(submissions)))
    
        # Repeat the submissions so that they each occur load times.
        extras = len(students)*k - len(submissions)*(load - 1);
        repeatedSubmissions = [x for x in submissions for i in range(load-1)]
        more = submissionsList[:extras]
        repeatedSubmissions = repeatedSubmissions + more
        
    
        # Assign cover, and remove covered submissions from submissions list
        assignments = cover;
        for s in students:
            for currentSubmission in assignments[s]:
                repeatedSubmissions.remove(currentSubmission);
        
        permutedSubmissions = random.sample(repeatedSubmissions,len(repeatedSubmissions));
        repeatedStudents = [x for x in studentList for i in range(k-1)]
        permutedStudents = random.sample(repeatedStudents,len(repeatedStudents));
    
        for s in permutedStudents:
            for currentSubmission in permutedSubmissions:
                assignments[s].append(currentSubmission);
                if not(check_assignment(groups,assignments)):
                    assignments[s].remove(currentSubmission);
                else:
                    permutedSubmissions.remove(currentSubmission);
                    break;
        
        done = True;
        
        for s in students:
            if (len(assignments[s]) != k):
                done = False;
        
        if done:
            break;
    
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
    
    #print(load)
    #print(len(submissions))
    #print(len(students))
    #print(extras)
    
    if not(done) and debug:
        print("Bad Cover!")
        return -1;
      
    # print the cover
    # here one can also output to file, etc.
    #print("Cover: ");
    #print(invert_dictlist_dup(cover));
    
    return assignments
    

# make sure nobody is assigned own assignment or duplicates
def check_assignment(groups,assignments):
    # maps students to their own submission
    
    exclude = invert_dictlist(groups)

    passed = True
    
    for s in assignments.keys():
        if exclude[s] in assignments[s]:
            #print("Student " + s + " assigned to own submission\n")
            passed = False
        if len(assignments[s]) != len(set(assignments[s])):
            #print("Student " + s + " assigned duplicate submissions\n")
            passed = False
            
    return passed

# %%
# generate some group data
groups = { sub : [sub + x for x in ['1','2','3']] for sub in [ chr(ord('a') + z) for z in range(10)]}

# get assignments
assignments = peer_assignment(groups,3)

# print assignments
invert_dictlist_dup(assignments)
# Out:
# {'a': ['j3', 'i3', 'e1', 'g1', 'c1', 'j1', 'd1', 'h3', 'i2'],
#  'b': ['i1', 'h2', 'a2', 'f1', 'e1', 'e3', 'h1', 'g1', 'd1'],
#  'c': ['b2', 'a1', 'f2', 'b1', 'i1', 'h2', 'f3', 'h1', 'i2'],
#  'd': ['a3', 'g2', 'c2', 'f2', 'i1', 'a2', 'g1', 'j1', 'h3'],
#  'e': ['g2', 'd2', 'b2', 'b3', 'f1', 'g3', 'i3', 'c3', 'h3'],
#  'f': ['e2', 'j2', 'a1', 'h2', 'i3', 'h1', 'c1', 'd1', 'c3'],
#  'g': ['j2', 'a3', 'b1', 'd3', 'f3', 'c1', 'j1', 'h3', 'i2'],
#  'h': ['e2', 'j2', 'a3', 'b1', 'j3', 'd3', 'f3', 'g3', 'e3'],
#  'i': ['c2', 'd2', 'b3', 'j3', 'd3', 'a2', 'f1', 'g3', 'e3'],
#  'j': ['g2', 'c2', 'd2', 'b2', 'b3', 'a1', 'f2', 'e1', 'c3']}

# %%
peer_assignment(groups,3,True)
# Out:
# {'a1': ['j', 'b', 'e'],
#  'a2': ['b', 'i', 'e'],
#  'a3': ['h', 'g', 'd'],
#  'b1': ['h', 'a', 'i'],
#  'b2': ['f', 'j', 'd'],
#  'b3': ['j', 'a', 'g'],
#  'c1': ['a', 'e', 'i'],
#  'c2': ['j', 'i', 'f'],
#  'c3': ['j', 'f', 'g'],
#  'd1': ['a', 'f', 'g'],
#  'd2': ['j', 'i', 'e'],
#  'd3': ['g', 'h', 'c'],
#  'e1': ['b', 'a', 'f'],
#  'e2': ['h', 'i', 'd'],
#  'e3': ['b', 'f', 'd'],
#  'f1': ['b', 'e', 'g'],
#  'f2': ['j', 'c', 'g'],
#  'f3': ['h', 'c', 'j'],
#  'g1': ['b', 'e', 'f'],
#  'g2': ['j', 'i', 'c'],
#  'g3': ['h', 'd', 'f'],
#  'h1': ['b', 'e', 'i'],
#  'h2': ['b', 'g', 'i'],
#  'h3': ['a', 'e', 'd'],
#  'i1': ['b', 'e', 'g'],
#  'i2': ['a', 'c', 'd'],
#  'i3': ['a', 'c', 'h'],
#  'j1': ['a', 'f', 'c'],
#  'j2': ['h', 'd', 'c'],
#  'j3': ['h', 'd', 'c']}

# %%
# generate groups

L = [chr(ord('a') + z) for z in range(26)];
bigL = [x + y for x in L for y in L]
bigGroups = {sub : [sub + x for x in ['1','2','3']] for sub in bigL[:90]};
bigGroups['aa'].remove('aa1');
bigGroups['ab'].remove('ab1');
bigGroups['ac'].remove('ac1');
bigGroups['ad'].remove('ad1');
bigGroups['ae'].remove('ae1');
bigGroups['af'].remove('af1');
bigGroups['ag'].remove('ag1');
bigGroups['ah'].remove('ah1');
bigGroups['ai'].remove('ai1');
bigGroups['aj'].remove('aj1');
bigGroups['ak'].remove('ak1');
bigGroups['al'].remove('al1');
bigGroups['am'].remove('am1');
bigGroups['an'].remove('an1');
bigGroups['ao'].remove('ao1');
bigGroups['ap'].remove('ap1');
bigGroups['aq'].remove('aq1');
bigGroups['ar'].remove('ar1');
bigGroups['as'].remove('as1');
bigGroups['at'].remove('at1');
bigGroups['au'].remove('au1');
bigGroups['av'].remove('av1');
bigGroups['aw'].remove('aw1');
bigGroups['ax'].remove('ax1');
bigGroups['ay'].remove('ay1');
bigGroups['az'].remove('az1');


# generate assignments
debug = True;
assignments = peer_assignment(bigGroups,3,debug)

# assignments
invert_dictlist_dup(assignments)
# Out:
# 9
# 90
# 244
# 12
# {'aa': ['dg2', 'bo3', 'be1', 'cq2', 'di1', 'bz2', 'cu1', 'ch3'],
#  'ab': ['de2', 'cu2', 'ak2', 'at3', 'bm3', 'cb3', 'cc1', 'dj2'],
#  'ac': ['ak3', 'ag2', 'as2', 'dh3', 'df3', 'bd1', 'cm2', 'cu1'],
#  'ad': ['ax3', 'dc3', 'ao3', 'af2', 'af3', 'bs1', 'cm1', 'ce2'],
#  'ae': ['dk1', 'bf3', 'cl1', 'bw1', 'cb1', 'cd3', 'df1', 'az3'],
#  'af': ['av3', 'bk1', 'aj2', 'dj3', 'am3', 'ct2', 'br3', 'bs1'],
#  'ag': ['cf2', 'cg2', 'ck2', 'bk3', 'cz1', 'cy1', 'cq3', 'br1'],
#  'ah': ['cu2', 'ck2', 'bo2', 'au3', 'ag2', 'ce3', 'bo1', 'cd1', 'di3'],
#  'ai': ['cd2', 'bp3', 'cx1', 'cw1', 'bc2', 'ay3', 'aq2', 'ch3'],
#  'aj': ['dk1', 'ac2', 'ab3', 'ci3', 'ag3', 'az2', 'be2', 'cb3'],
#  'ak': ['dl2', 'bf2', 'bq3', 'ai3', 'bj1', 'cn2', 'cs3', 'bb1'],
#  'al': ['cs2', 'av3', 'ay2', 'bk1', 'bo1', 'cj3', 'as3', 'cv2'],
#  'am': ['bk3', 'be3', 'cp3', 'df3', 'cl2', 'bg3', 'cd3', 'ca3'],
#  'an': ['cp2', 'bv3', 'bq1', 'cu3', 'ba2', 'dh2', 'ba1', 'ay3'],
#  'ao': ['bf3', 'aa3', 'ah3', 'ac3', 'dd3', 'cw2', 'bl1', 'br3'],
#  'ap': ['dj1', 'cr3', 'dd1', 'au2', 'di1', 'dl1', 'cr1', 'da1'],
#  'aq': ['bp3', 'ay2', 'ar3', 'cq1', 'cx1', 'cw1', 'bm1', 'cs1', 'bz2'],
#  'ar': ['be2', 'da3', 'bu3', 'br1', 'ch3', 'bh3', 'ck3', 'ci2'],
#  'as': ['cz3', 'db2', 'bt2', 'db3', 'az3', 'bb2', 'bm2', 'bu1'],
#  'at': ['ct3', 'az2', 'cp1', 'bc3', 'co1', 'ct1', 'bv1', 'bb3'],
#  'au': ['cw3', 'bv2', 'bx2', 'dk2', 'bd2', 'cj1', 'bb3', 'ck3'],
#  'av': ['ad3', 'bq3', 'bd2', 'bk2', 'bt2', 'az3', 'da3', 'ci2'],
#  'aw': ['cb1', 'bd1', 'am3', 'bj2', 'ai3', 'df1', 'cg1', 'cc2'],
#  'ax': ['cj2', 'bl3', 'ap2', 'dd2', 'cs3', 'cv2', 'bc2', 'cc1'],
#  'ay': ['cq1', 'de3', 'dj1', 'at3', 'cj3', 'ct1', 'cy1', 'by2'],
#  'az': ['dc2', 'ar2', 'ac3', 'bh2', 'ad2', 'dd2', 'dh2', 'bc1'],
#  'ba': ['dc2', 'cj2', 'al2', 'dj1', 'cb2', 'ab3', 'ao3', 'cf3'],
#  'bb': ['bf1', 'co2', 'dk3', 'bx3', 'dg3', 'bh2', 'ad2', 'ca1'],
#  'bc': ['bv2', 'cz3', 'cv1', 'bd1', 'dl3', 'cv3', 'ba2', 'cf3'],
#  'bd': ['dk1', 'cx3', 'bn1', 'at2', 'cq3', 'cb3', 'ai2', 'aq2'],
#  'be': ['dl1', 'bp2', 'cs1', 'cd1', 'da2', 'ba2', 'dh1', 'ce2'],
#  'bf': ['df2', 'cd1', 'bh1', 'bg1', 'ct2', 'bj1', 'ae3', 'cn2'],
#  'bg': ['cn1', 'ch2', 'dl2', 'cn3', 'av2', 'ab2', 'ba3', 'cx2', 'bc1'],
#  'bh': ['bw2', 'di2', 'an2', 'ce3', 'df1', 'di3', 'dc3', 'cc2'],
#  'bi': ['bd3', 'cq1', 'au3', 'bf1', 'dd3', 'bx3', 'bu3', 'ck3'],
#  'bj': ['cs2', 'au3', 'bw3', 'az2', 'db1', 'bb3', 'cv2', 'ch1'],
#  'bk': ['cu2', 'bo2', 'cy3', 'cg3', 'bw3', 'bi2', 'bn2', 'af3'],
#  'bl': ['cj2', 'ax2', 'an3', 'br2', 'co3', 'bo3', 'cm3', 'ay3'],
#  'bm': ['ar3', 'de3', 'cz2', 'ca2', 'bh2', 'bx1', 'ai3', 'ba1'],
#  'bn': ['bq2', 'as2', 'am2', 'aa3', 'bq1', 'af2', 'ai2', 'br1'],
#  'bo': ['dg1', 'an2', 'ar2', 'am2', 'bm1', 'bz1', 'bq3', 'bw3', 'aw3'],
#  'bp': ['bt1', 'bu2', 'bq1', 'ck1', 'ae2', 'ao3', 'af3', 'cx3'],
#  'bq': ['bf1', 'ah3', 'cp1', 'aw2', 'cl2', 'bl3', 'cm1', 'bn1'],
#  'br': ['bk3', 'bg2', 'dh3', 'ag3', 'ah3', 'bt3', 'cu3', 'ae3'],
#  'bs': ['ch2', 'di2', 'ar2', 'bp2', 'ad2', 'bc3', 'db3', 'dd2'],
#  'bt': ['cl3', 'ar3', 'dl1', 'bl2', 'bl1', 'df3', 'at2', 'bc1'],
#  'bu': ['be1', 'by1', 'bm1', 'au2', 'co1', 'aw2', 'be2', 'cl2'],
#  'bv': ['bs3', 'ce1', 'bf2', 'bq2', 'ak3', 'aj3', 'al2', 'as3', 'by2'],
#  'bw': ['dh3', 'bk2', 'aw2', 'db1', 'bm3', 'bs2', 'ck1', 'cx2'],
#  'bx': ['bi1', 'ci1', 'bv3', 'cy3', 'bp1', 'bl2', 'aa2', 'ct1'],
#  'by': ['bt1', 'dj3', 'aa3', 'be3', 'dd3', 'bw1', 'db1', 'cx3'],
#  'bz': ['bd3', 'cw3', 'av3', 'bi3', 'bn3', 'ci1', 'an3', 'br3', 'bn2'],
#  'ca': ['cf2', 'cd2', 'al3', 'bi1', 'dc2', 'cf1', 'cl3', 'ax2', 'bn3'],
#  'cb': ['cn1', 'cy2', 'ac2', 'cj1', 'bj2', 'bg1', 'bj1', 'aq2'],
#  'cc': ['ci3', 'ag3', 'aa2', 'aq3', 'bu2', 'dk2', 'bp2', 'cv3'],
#  'cd': ['by3', 'ao2', 'cc3', 'cr2', 'cz2', 'di1', 'bm2', 'ap2'],
#  'ce': ['ch2', 'cn3', 'bi3', 'dk2', 'cs1', 'cd3', 'bb2', 'ba1'],
#  'cf': ['av2', 'ap3', 'be1', 'by1', 'dj3', 'de3', 'cz2', 'cq2', 'ae2'],
#  'cg': ['cs2', 'dc1', 'bb1', 'ch1', 'de1', 'da2', 'cm2', 'cu1'],
#  'ch': ['an3', 'al2', 'dg1', 'cc3', 'bz1', 'bs1', 'at2', 'bu3'],
#  'ci': ['br2', 'aj3', 'bx2', 'cp3', 'bn2', 'bu1', 'bn1', 'dj2'],
#  'cj': ['cf2', 'ak2', 'cg3', 'ci3', 'bh1', 'ae3', 'cm1', 'cq3'],
#  'ck': ['ax2', 'cz3', 'dd1', 'cb1', 'ch1', 'cm2', 'dc3', 'bh3'],
#  'cl': ['bj3', 'bu2', 'bi2', 'bs2', 'ck1', 'bg3', 'bb1', 'ci2'],
#  'cm': ['cd2', 'ak3', 'dg1', 'aj2', 'bx1', 'ct2', 'cn2', 'bc2'],
#  'cn': ['av2', 'ab2', 'cp2', 'bq2', 'ay2', 'ck2', 'dg3', 'bb2'],
#  'co': ['br2', 'ad3', 'cb2', 'at3', 'ca2', 'ab3', 'cz1', 'dh1'],
#  'cp': ['ct3', 'by3', 'cy2', 'cw2', 'dg3', 'dc1', 'dh2', 'by2'],
#  'cq': ['al3', 'ce1', 'ah2', 'cb2', 'aq3', 'bs2', 'bh1', 'cv3'],
#  'cr': ['ax3', 'db2', 'dd1', 'cw2', 'cm3', 'ca3', 'dh1', 'af2'],
#  'cs': ['bf3', 'dg2', 'am2', 'cz1', 'bo1', 'bl1', 'dk3', 'bm3'],
#  'ct': ['cp2', 'bn3', 'bf2', 'an2', 'co2', 'cr3', 'cu3', 'bg1'],
#  'cu': ['ci1', 'ce1', 'bp3', 'cw1', 'bw2', 'cv1', 'cr1', 'cs3'],
#  'cv': ['co3', 'cl1', 'ap3', 'ca2', 'bj2', 'aw3', 'bv1', 'di3'],
#  'cw': ['ba3', 'cy2', 'dg2', 'bg2', 'cy3', 'bp1', 'cj1', 'dl3', 'cy1'],
#  'cx': ['aj3', 'ao2', 'cq2', 'aq3', 'cr1', 'bg3', 'ae2', 'bz3'],
#  'cy': ['ct3', 'bs3', 'cx1', 'co2', 'bc3', 'bz2', 'de1', 'cc2'],
#  'cz': ['al3', 'df2', 'de2', 'cg2', 'cp1', 'db3', 'cg1', 'bz3'],
#  'da': ['cn1', 'ab2', 'bi1', 'bo2', 'ax3', 'dk3', 'ca1', 'bl3'],
#  'db': ['bl2', 'cj3', 'bx1', 'cm3', 'bd2', 'bw1', 'bt3', 'as3'],
#  'dc': ['as2', 'bo3', 'aj2', 'cr2', 'cl1', 'bx2', 'cv1', 'bi2', 'bu1'],
#  'dd': ['cf1', 'cl3', 'bs3', 'bj3', 'ap3', 'au2', 'bx3', 'de1'],
#  'de': ['cn3', 'ah2', 'db2', 'bk2', 'ca3', 'bm2', 'da1', 'cx2'],
#  'df': ['cw3', 'bk1', 'cc3', 'ak2', 'cg3', 'bt1', 'bj3', 'co3', 'ac2'],
#  'dg': ['ba3', 'df2', 'bp1', 'by1', 'cr3', 'bt3', 'bv1', 'cg1'],
#  'dh': ['dl2', 'cf1', 'bi3', 'ce3', 'am3', 'da1', 'ap2', 'dc1'],
#  'di': ['be3', 'ac3', 'cp3', 'dl3', 'ca1', 'da2', 'ce2', 'ai2'],
#  'dj': ['bv3', 'bg2', 'cr2', 'co1', 'aw3', 'cc1', 'cf3', 'bz3'],
#  'dk': ['bd3', 'ad3', 'ag2', 'bz1', 'aa2', 'bt2', 'da3', 'bh3'],
#  'dl': ['bw2', 'de2', 'di2', 'cg2', 'bv2', 'by3', 'ah2', 'ao2', 'dj2']}

# %%
peer_assignment(bigGroups,3)
# Out:
# 9
# 90
# 244
# 12
# {'aa2': ['cc', 'ai', 'cs'],
#  'aa3': ['ao', 'ab', 'bk'],
#  'ab2': ['bg', 'bu', 'ci'],
#  'ab3': ['co', 'dh', 'bi'],
#  'ac2': ['df', 'bl', 'cj'],
#  'ac3': ['ao', 'de', 'au'],
#  'ad2': ['bb', 'cb', 'cn'],
#  'ad3': ['co', 'cb', 'by'],
#  'ae2': ['cf', 'dj', 'cj'],
#  'ae3': ['bf', 'cb', 'ay'],
#  'af2': ['ad', 'bv', 'ak'],
#  'af3': ['ad', 'aj', 'cn'],
#  'ag2': ['ah', 'bp', 'bc'],
#  'ag3': ['cc', 'ab', 'ac'],
#  'ah2': ['dl', 'bn', 'dg'],
#  'ah3': ['ao', 'ae', 'bs'],
#  'ai2': ['bd', 'cx', 'cu'],
#  'ai3': ['aw', 'ba', 'bl'],
#  'aj2': ['dc', 'cp', 'cj'],
#  'aj3': ['bv', 'cm', 'cr'],
#  'ak2': ['df', 'dh', 'az'],
#  'ak3': ['bv', 'cu', 'dd'],
#  'al2': ['bv', 'az', 'ch'],
#  'al3': ['ca', 'az', 'au'],
#  'am2': ['bo', 'bh', 'de'],
#  'am3': ['aw', 'bu', 'aa'],
#  'an2': ['bo', 'bg', 'af'],
#  'an3': ['bz', 'bm', 'cz'],
#  'ao2': ['dl', 'al', 'ae'],
#  'ao3': ['ad', 'cz', 'da'],
#  'ap2': ['ax', 'ch', 'av'],
#  'ap3': ['cf', 'ba', 'be'],
#  'aq2': ['bd', 'bl', 'bt'],
#  'aq3': ['cc', 'bu', 'ak'],
#  'ar2': ['bo', 'by', 'bq'],
#  'ar3': ['aq', 'cl', 'ay'],
#  'as2': ['dc', 'aa', 'au'],
#  'as3': ['db', 'bt', 'bn'],
#  'at2': ['bd', 'ck', 'br'],
#  'at3': ['co', 'bs', 'az'],
#  'au2': ['ap', 'cy', 'cd'],
#  'au3': ['ah', 'cp', 'bs'],
#  'av2': ['bg', 'cs', 'ci'],
#  'av3': ['bz', 'al', 'af'],
#  'aw2': ['bw', 'cv', 'bu'],
#  'aw3': ['dj', 'ba', 'da'],
#  'ax2': ['ca', 'bx', 'ct'],
#  'ax3': ['ad', 'cl', 'ag'],
#  'ay2': ['aq', 'dd', 'av'],
#  'ay3': ['an', 'bh', 'be'],
#  'az2': ['at', 'di', 'cm'],
#  'az3': ['as', 'dk', 'bx'],
#  'ba1': ['an', 'da', 'bc'],
#  'ba2': ['an', 'cn', 'bj'],
#  'ba3': ['bg', 'dd', 'cn'],
#  'bb1': ['cg', 'cq', 'ac'],
#  'bb2': ['as', 'dj', 'al'],
#  'bb3': ['at', 'bi', 'br'],
#  'bc1': ['bg', 'br', 'bt'],
#  'bc2': ['ax', 'bh', 'cd'],
#  'bc3': ['at', 'bt', 'dd'],
#  'bd1': ['aw', 'cn', 'cy'],
#  'bd2': ['db', 'aa', 'cr'],
#  'bd3': ['bz', 'bk', 'dg'],
#  'be1': ['cf', 'aa', 'bu'],
#  'be2': ['ar', 'ba', 'by'],
#  'be3': ['am', 'ab', 'bj'],
#  'bf1': ['bb', 'al', 'bl'],
#  'bf2': ['bv', 'ce', 'ae'],
#  'bf3': ['ao', 'cx', 'cq'],
#  'bg1': ['bf', 'br', 'de'],
#  'bg2': ['cw', 'dl', 'au'],
#  'bg3': ['am', 'bn', 'ct'],
#  'bh1': ['bf', 'br', 'af'],
#  'bh2': ['bb', 'cy', 'di'],
#  'bh3': ['ar', 'cs', 'az'],
#  'bi1': ['ca', 'bs', 'ci'],
#  'bi2': ['dc', 'ay', 'cf'],
#  'bi3': ['bz', 'bc', 'bo'],
#  'bj1': ['bf', 'dk', 'ba'],
#  'bj2': ['aw', 'cq', 'ct'],
#  'bj3': ['df', 'ac', 'bi'],
#  'bk1': ['df', 'cv', 'cr'],
#  'bk2': ['bw', 'bp', 'dk'],
#  'bk3': ['am', 'cd', 'ct'],
#  'bl1': ['ao', 'bm', 'ai'],
#  'bl2': ['db', 'cy', 'cp'],
#  'bl3': ['ax', 'dk', 'ae'],
#  'bm1': ['bo', 'bl', 'ba'],
#  'bm2': ['as', 'bp', 'bj'],
#  'bm3': ['bw', 'cr', 'dg'],
#  'bn1': ['bd', 'dj', 'dh'],
#  'bn2': ['bz', 'ch', 'bi'],
#  'bn3': ['bz', 'ct', 'ab'],
#  'bo1': ['ah', 'br', 'bi'],
#  'bo2': ['ah', 'dd', 'cx'],
#  'bo3': ['dc', 'cz', 'ac'],
#  'bp1': ['cw', 'bj', 'bx'],
#  'bp2': ['cc', 'dg', 'ac'],
#  'bp3': ['aq', 'ce', 'bk'],
#  'bq1': ['an', 'cq', 'cx'],
#  'bq2': ['bv', 'cp', 'cm'],
#  'bq3': ['bo', 'cb', 'be'],
#  'br1': ['ar', 'dh', 'cy'],
#  'br2': ['co', 'bl', 'cy'],
#  'br3': ['ao', 'av', 'bz'],
#  'bs1': ['ad', 'da', 'ak'],
#  'bs2': ['bw', 'bi', 'bx'],
#  'bs3': ['bv', 'bu', 'da'],
#  'bt1': ['df', 'bl', 'af'],
#  'bt2': ['as', 'cn', 'dh'],
#  'bt3': ['db', 'ba', 'ci'],
#  'bu1': ['as', 'be', 'ak'],
#  'bu2': ['cc', 'cj', 'cx'],
#  'bu3': ['ar', 'au', 'cd'],
#  'bv1': ['at', 'dc', 'bs'],
#  'bv2': ['dl', 'by', 'cx'],
#  'bv3': ['an', 'bk', 'ai'],
#  'bw1': ['db', 'av', 'al'],
#  'bw2': ['dl', 'br', 'dh'],
#  'bw3': ['bo', 'be', 'ct'],
#  'bx1': ['db', 'cj', 'bp'],
#  'bx2': ['dc', 'ce', 'ci'],
#  'bx3': ['bb', 'cs', 'av'],
#  'by1': ['cf', 'af', 'ch'],
#  'by2': ['bv', 'da', 'cv'],
#  'by3': ['dl', 'bk', 'bx'],
#  'bz1': ['bo', 'di', 'ag'],
#  'bz2': ['aq', 'bs', 'ag'],
#  'bz3': ['dj', 'au', 'ck'],
#  'ca1': ['bb', 'dk', 'bq'],
#  'ca2': ['co', 'dh', 'cj'],
#  'ca3': ['am', 'ck', 'ct'],
#  'cb1': ['aw', 'ai', 'bq'],
#  'cb2': ['co', 'aj', 'ay'],
#  'cb3': ['bd', 'cz', 'dd'],
#  'cc1': ['ax', 'bk', 'ae'],
#  'cc2': ['aw', 'ay', 'bm'],
#  'cc3': ['df', 'cd', 'dh'],
#  'cd1': ['bf', 'af', 'cu'],
#  'cd2': ['ca', 'ay', 'bq'],
#  'cd3': ['am', 'bq', 'bt'],
#  'ce1': ['bv', 'cm', 'cu'],
#  'ce2': ['ad', 'au', 'dg'],
#  'ce3': ['ah', 'bh', 'cl'],
#  'cf1': ['ca', 'cp', 'aj'],
#  'cf2': ['ca', 'bc', 'aj'],
#  'cf3': ['da', 'dj', 'ch'],
#  'cg1': ['aw', 'cs', 'cp'],
#  'cg2': ['dl', 'bn', 'cy'],
#  'cg3': ['df', 'de', 'al'],
#  'ch1': ['cg', 'bp', 'cb'],
#  'ch2': ['bg', 'ce', 'cd'],
#  'ch3': ['ar', 'av', 'cv'],
#  'ci1': ['bz', 'dj', 'dk'],
#  'ci2': ['ar', 'cy', 'bq'],
#  'ci3': ['cc', 'cq', 'ce'],
#  'cj1': ['cw', 'ai', 'dj'],
#  'cj2': ['ax', 'bx', 'bh'],
#  'cj3': ['db', 'cr', 'bs'],
#  'ck1': ['bw', 'ba', 'aj'],
#  'ck2': ['ah', 'ca', 'de'],
#  'ck3': ['ar', 'cl', 'ci'],
#  'cl1': ['dc', 'cz', 'bc'],
#  'cl2': ['am', 'cv', 'ac'],
#  'cl3': ['ca', 'bk', 'af'],
#  'cm1': ['ad', 'cl', 'br'],
#  'cm2': ['cg', 'ag', 'bt'],
#  'cm3': ['db', 'aa', 'al'],
#  'cn1': ['bg', 'by', 'bh'],
#  'cn2': ['bf', 'aj', 'bm'],
#  'cn3': ['bg', 'ak', 'ag'],
#  'co1': ['at', 'dk', 'ce'],
#  'co2': ['bb', 'ag', 'ak'],
#  'co3': ['df', 'ck', 'ay'],
#  'cp1': ['at', 'ab', 'bp'],
#  'cp2': ['an', 'ah', 'bm'],
#  'cp3': ['am', 'cr', 'dk'],
#  'cq1': ['aq', 'cv', 'bj'],
#  'cq2': ['cf', 'aj', 'bm'],
#  'cq3': ['bd', 'ab', 'dg'],
#  'cr1': ['ap', 'bn', 'cd'],
#  'cr2': ['dc', 'ct', 'bk'],
#  'cr3': ['ap', 'cs', 'ce'],
#  'cs1': ['aq', 'bp', 'bq'],
#  'cs2': ['cg', 'ag', 'bx'],
#  'cs3': ['ax', 'bs', 'ab'],
#  'ct1': ['at', 'cz', 'bt'],
#  'ct2': ['bf', 'di', 'cj'],
#  'ct3': ['at', 'ac', 'df'],
#  'cu1': ['cg', 'bt', 'da'],
#  'cu2': ['ah', 'af', 'cz'],
#  'cu3': ['an', 'cn', 'de'],
#  'cv1': ['dc', 'bi', 'ae'],
#  'cv2': ['ax', 'bq', 'bn'],
#  'cv3': ['cc', 'bc', 'ak'],
#  'cw1': ['aq', 'ch', 'cl'],
#  'cw2': ['ao', 'cp', 'di'],
#  'cw3': ['bz', 'cr', 'ay'],
#  'cx1': ['aq', 'az', 'cl'],
#  'cx2': ['bw', 'bh', 'aq'],
#  'cx3': ['bd', 'ae', 'al'],
#  'cy1': ['cw', 'aa', 'bn'],
#  'cy2': ['cw', 'cu', 'cm'],
#  'cy3': ['cw', 'bm', 'ai'],
#  'cz1': ['co', 'av', 'cb'],
#  'cz2': ['cf', 'ck', 'di'],
#  'cz3': ['as', 'ck', 'cu'],
#  'da1': ['ap', 'aj', 'ck'],
#  'da2': ['cg', 'ae', 'az'],
#  'da3': ['ar', 'av', 'cw'],
#  'db1': ['bw', 'bx', 'cq'],
#  'db2': ['as', 'bn', 'bl'],
#  'db3': ['as', 'bh', 'bj'],
#  'dc1': ['cg', 'di', 'de'],
#  'dc2': ['ca', 'cv', 'bu'],
#  'dc3': ['ad', 'bj', 'ce'],
#  'dd1': ['ap', 'ci', 'au'],
#  'dd2': ['ax', 'bm', 'bi'],
#  'dd3': ['ao', 'ai', 'bc'],
#  'de1': ['cg', 'cz', 'cs'],
#  'de2': ['dl', 'ck', 'cb'],
#  'de3': ['cf', 'by', 'bc'],
#  'df1': ['aw', 'be', 'bj'],
#  'df2': ['bf', 'cv', 'dd'],
#  'df3': ['am', 'ac', 'cm'],
#  'dg1': ['bo', 'cp', 'di'],
#  'dg2': ['cw', 'bu', 'bp'],
#  'dg3': ['bb', 'be', 'cb'],
#  'dh1': ['co', 'cs', 'cq'],
#  'dh2': ['an', 'cx', 'cj'],
#  'dh3': ['bw', 'by', 'cl'],
#  'di1': ['ap', 'dg', 'aa'],
#  'di2': ['dl', 'cn', 'be'],
#  'di3': ['ah', 'cm', 'ai'],
#  'dj1': ['ap', 'az', 'dg'],
#  'dj2': ['ci', 'ak', 'cx'],
#  'dj3': ['cf', 'dd', 'ag'],
#  'dk1': ['bd', 'cm', 'ab'],
#  'dk2': ['cc', 'aa', 'cu'],
#  'dk3': ['bb', 'cu', 'cd'],
#  'dl1': ['ap', 'ch', 'cr'],
#  'dl2': ['bg', 'by', 'cq'],
#  'dl3': ['cw', 'ch', 'de']}
