# %%
import random
import math

# invert a dictionary of lists (assuming no duplicates)
def invert_dictlist(d):
    return dict( (v,k) for k in d for v in d[k] )

# invert a dictionary of lists (with duplicates)
def invert_dictlist_dup(d):
    values = set(a for b in d.values() for a in b)
    reverse_d = dict((new_key, [key for key,value in d.items() if new_key in value]) for new_key in values)
    return reverse_d

# %%
# assign students in groups to k submissions.
def peer_assignment(groups,k,coverList=[],debug=False):
    """Given no cover, first generate a cover with the first few submissions"""
    """Then, generate the rest of the assignments"""
    
    submissions = groups.keys()
    
    # lookup for which submissions to exclude from a particular student.
    exclude = invert_dictlist(groups)
    students = exclude.keys()
    studentList = list(students);

 
    # load = ceil(number of students * k / number of submissions)
    # this is how many copies of random submission lists we need.
    load = int(math.ceil((len(students) * k) / len(submissions)))
    
    # Repeat the submissions so that they each occur load times.
    repeatedSubmissions = [x for x in submissions for i in range(load-1)]
    
    # initialize empty assignment and cover
    assignments = {s : [] for s in students}
    cover = {s : [] for s in students}
    
    # cover with the first few submissions. Every time a submission is used, remove it.
    # This way, each submission is repeated at most load # of times.
    for s in students:
        for currentSubmission in repeatedSubmissions:
            if currentSubmission not in exclude[s]:
                assignments[s].append(currentSubmission);
                repeatedSubmissions.remove(currentSubmission);
                cover[s].append(currentSubmission);
                break;
    
    assignments = peer_assignment_with_cover(groups,k,cover,coverList);
    
    if (assignments == -1) and debug:
        print("Couldn't generate good cover!");
    
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
            
    if not(done) and debug:
        print("Not a good assignment!")
        return -1;
    
    return assignments;
    
def peer_assignment_with_cover_submissions(groups,k,coverSubmissions,coverList=[],debug=False):
    """Given a list of submissions, generate a cover using those submissions"""
    """Then, generate the rest of the assignments"""
    
    submissions = groups.keys()
    
    # lookup for which submissions to exclude from a particular student.
    exclude = invert_dictlist(groups)
    students = exclude.keys()
    studentList = list(students);

    # load = ceil(number of students * k / number of submissions)
    # this is how many copies of random submission lists we need.
    load = int(math.ceil((len(students) * k) / len(submissions)))
    
    repeatedCoverSubmissions = [x for x in coverSubmissions for i in range(load-1)]
    
    # initialize empty cover
    cover = {s : [] for s in students}
    
    # cover with the first few of coverSubmissions
    for s in students:
        for currentSubmission in repeatedCoverSubmissions:
            if currentSubmission not in exclude[s]:
                repeatedCoverSubmissions.remove(currentSubmission);
                cover[s].append(currentSubmission);
                break;
    
    for s in students:
        if len(assignments[s]) == 0:
            if (debug):
                print("Error: Submissions cannot cover students!")
            return -1;
        
    assignments = peer_assignment_with_cover(groups,k,cover,coverList);
    
    if (assignments == -1) and debug:
        print("Couldn't generate good cover!");
        return -1;
    
     
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
            
    if not(done) and debug:
        print("Not a good assignment!")
        return -1;
    
    return assignments;
    
def peer_assignment_with_cover(groups,k,cover,coverList = [],debug=False):
    """Given an entire cover of (student,submission) pairs, generate the rest of the assignments"""
    
    
    for i in range(10000):
        
        submissions = groups.keys()
        submissionsList = list(submissions);
        
        # lookup for which submissions to exclude from a particular student.
        exclude = invert_dictlist(groups)
        students = exclude.keys()
        studentList = list(students);
    
     
        # load = ceil(number of students * k / number of submissions)
        # this is how many copies of random submission lists we need.
        load = int(math.ceil((len(students) * k) / len(submissions)))
    
        # Repeat the submissions so that they each occur load times.
        extras = len(students)*k - len(submissions)*(load - 1);
        repeatedSubmissions = [x for x in submissions for i in range(load-1)]
        more = submissionsList[:extras]
        repeatedSubmissions = repeatedSubmissions + more
        
    
        # Assign cover, and remove covered submissions from submissions list
        assignments = cover;
        for s in students:
            for currentSubmission in assignments[s]:
                repeatedSubmissions.remove(currentSubmission);
        
        permutedSubmissions = random.sample(repeatedSubmissions,len(repeatedSubmissions));
        repeatedStudents = [x for x in studentList for i in range(k-1)]
        permutedStudents = random.sample(repeatedStudents,len(repeatedStudents));
    
        for s in permutedStudents:
            for currentSubmission in permutedSubmissions:
                assignments[s].append(currentSubmission);
                if not(check_assignment(groups,assignments)):
                    assignments[s].remove(currentSubmission);
                else:
                    permutedSubmissions.remove(currentSubmission);
                    break;
        
        done = True;
        
        for s in students:
            if (len(assignments[s]) != k):
                done = False;
        
        if done:
            break;
    
    done = True;
    for s in students:
        if (len(assignments[s]) != k):
            done = False;
    
    if not(done) and debug:
        print("Bad Cover!")
        return -1;
      
        
    coverList.append(cover);
    return assignments
    

# make sure nobody is assigned own assignment or duplicates
def check_assignment(groups,assignments):
    # maps students to their own submission
    
    exclude = invert_dictlist(groups)

    passed = True
    
    for s in assignments.keys():
        if exclude[s] in assignments[s]:
            #print("Student " + s + " assigned to own submission\n")
            passed = False
        if len(assignments[s]) != len(set(assignments[s])):
            #print("Student " + s + " assigned duplicate submissions\n")
            passed = False
            
    return passed

# %%
# generate some group data
groups = { sub : [sub + x for x in ['1','2','3']] for sub in [ chr(ord('a') + z) for z in range(10)]}

# get assignments
coverList = [];
assignments = peer_assignment(groups,3,coverList);

# print assignments and cover
print(coverList)
invert_dictlist_dup(assignments)
# Out:
# [{'b2': ['i', 'c', 'a'], 'g2': ['i', 'd', 'f'], 'c1': ['i', 'a', 'd'], 'a2': ['h', 'f', 'b'], 'h3': ['j', 'a', 'f'], 'b3': ['a', 'i', 'd'], 'h2': ['i', 'a', 'j'], 'b1': ['i', 'f', 'd'], 'e1': ['h', 'a', 'b'], 'j3': ['e', 'g', 'b'], 'e3': ['h', 'c', 'd'], 'f1': ['i', 'e', 'c'], 'f2': ['e', 'c', 'd'], 'i2': ['e', 'f', 'a'], 'j2': ['e', 'g', 'i'], 'd2': ['e', 'c', 'h'], 'd3': ['e', 'g', 'b'], 'd1': ['i', 'j', 'g'], 'g3': ['h', 'a', 'b'], 'i3': ['h', 'c', 'g'], 'f3': ['h', 'g', 'd'], 'i1': ['e', 'j', 'g'], 'g1': ['h', 'c', 'b'], 'h1': ['j', 'c', 'd'], 'c3': ['e', 'a', 'b'], 'a3': ['h', 'f', 'j'], 'a1': ['j', 'f', 'b'], 'e2': ['j', 'g', 'f'], 'j1': ['c', 'g', 'd'], 'c2': ['j', 'b', 'f']}]
# {'a': ['b2', 'c1', 'h3', 'b3', 'h2', 'e1', 'i2', 'g3', 'c3'],
#  'b': ['a2', 'e1', 'j3', 'd3', 'g3', 'g1', 'c3', 'a1', 'c2'],
#  'c': ['b2', 'e3', 'f1', 'f2', 'd2', 'i3', 'g1', 'h1', 'j1'],
#  'd': ['g2', 'c1', 'b3', 'b1', 'e3', 'f2', 'f3', 'h1', 'j1'],
#  'e': ['j3', 'f1', 'f2', 'i2', 'j2', 'd2', 'd3', 'i1', 'c3'],
#  'f': ['g2', 'a2', 'h3', 'b1', 'i2', 'a3', 'a1', 'e2', 'c2'],
#  'g': ['j3', 'j2', 'd3', 'd1', 'i3', 'f3', 'i1', 'e2', 'j1'],
#  'h': ['a2', 'e1', 'e3', 'd2', 'g3', 'i3', 'f3', 'g1', 'a3'],
#  'i': ['b2', 'g2', 'c1', 'b3', 'h2', 'b1', 'f1', 'j2', 'd1'],
#  'j': ['h3', 'h2', 'd1', 'i1', 'h1', 'a3', 'a1', 'e2', 'c2']}

# %%
peer_assignment(groups,3,True)
# Out:
# {'a1': ['j', 'b', 'e'],
#  'a2': ['b', 'i', 'e'],
#  'a3': ['h', 'g', 'd'],
#  'b1': ['h', 'a', 'i'],
#  'b2': ['f', 'j', 'd'],
#  'b3': ['j', 'a', 'g'],
#  'c1': ['a', 'e', 'i'],
#  'c2': ['j', 'i', 'f'],
#  'c3': ['j', 'f', 'g'],
#  'd1': ['a', 'f', 'g'],
#  'd2': ['j', 'i', 'e'],
#  'd3': ['g', 'h', 'c'],
#  'e1': ['b', 'a', 'f'],
#  'e2': ['h', 'i', 'd'],
#  'e3': ['b', 'f', 'd'],
#  'f1': ['b', 'e', 'g'],
#  'f2': ['j', 'c', 'g'],
#  'f3': ['h', 'c', 'j'],
#  'g1': ['b', 'e', 'f'],
#  'g2': ['j', 'i', 'c'],
#  'g3': ['h', 'd', 'f'],
#  'h1': ['b', 'e', 'i'],
#  'h2': ['b', 'g', 'i'],
#  'h3': ['a', 'e', 'd'],
#  'i1': ['b', 'e', 'g'],
#  'i2': ['a', 'c', 'd'],
#  'i3': ['a', 'c', 'h'],
#  'j1': ['a', 'f', 'c'],
#  'j2': ['h', 'd', 'c'],
#  'j3': ['h', 'd', 'c']}

# %%
# generate groups

L = [chr(ord('a') + z) for z in range(26)];
bigL = [x + y for x in L for y in L]
bigGroups = {sub : [sub + x for x in ['1','2','3']] for sub in bigL[:90]};
bigGroups['aa'].remove('aa1');
bigGroups['ab'].remove('ab1');
bigGroups['ac'].remove('ac1');
bigGroups['ad'].remove('ad1');
bigGroups['ae'].remove('ae1');
bigGroups['af'].remove('af1');
bigGroups['ag'].remove('ag1');
bigGroups['ah'].remove('ah1');
bigGroups['ai'].remove('ai1');
bigGroups['aj'].remove('aj1');
bigGroups['ak'].remove('ak1');
bigGroups['al'].remove('al1');
bigGroups['am'].remove('am1');
bigGroups['an'].remove('an1');
bigGroups['ao'].remove('ao1');
bigGroups['ap'].remove('ap1');
bigGroups['aq'].remove('aq1');
bigGroups['ar'].remove('ar1');
bigGroups['as'].remove('as1');
bigGroups['at'].remove('at1');
bigGroups['au'].remove('au1');
bigGroups['av'].remove('av1');
bigGroups['aw'].remove('aw1');
bigGroups['ax'].remove('ax1');
bigGroups['ay'].remove('ay1');
bigGroups['az'].remove('az1');


# generate assignments
coverList = [];
assignments = peer_assignment(bigGroups,3,coverList)

# assignments
print(coverList)
invert_dictlist_dup(assignments)
# Out:
# [{'an3': ['ce', 'cw', 'bn'], 'co3': ['ce', 'cg', 'ck'], 'cb2': ['ce', 'af', 'bn'], 'co2': ['ce', 'bd', 'dg'], 'bx1': ['ce', 'bn', 'bp'], 'ac3': ['ce', 'db', 'ai'], 'dh1': ['ce', 'bm', 'bf'], 'av2': ['ce', 'dg', 'cb'], 'bb1': ['at', 'bn', 'bs'], 'dk3': ['be', 'au', 'dc'], 'de1': ['be', 'ct', 'bu'], 'ay3': ['be', 'ba', 'cg'], 'ah2': ['cx', 'bu', 'ca'], 'cy1': ['be', 'bv', 'dc'], 'cw2': ['be', 'cu', 'av'], 'bq3': ['be', 'cj', 'br'], 'cs3': ['bw', 'ah', 'bh'], 'aw3': ['cy', 'cr', 'ck'], 'ct2': ['cy', 'cm', 'bv'], 'cv2': ['cy', 'cj', 'ct'], 'bj2': ['bk', 'cy', 'dj'], 'cc3': ['cy', 'bh', 'dg'], 'cj2': ['cy', 'af', 'cu'], 'ak3': ['dk', 'bi', 'bz'], 'bn1': ['cy', 'cr', 'ao'], 'cz1': ['cy', 'cn', 'cb'], 'bf1': ['al', 'av', 'bv'], 'be1': ['al', 'ca', 'bl'], 'bv1': ['al', 'bp', 'ao'], 'bh2': ['al', 'ay', 'di'], 'cj3': ['al', 'di', 'aq'], 'bd1': ['al', 'ae', 'az'], 'cr1': ['dk', 'cf', 'au'], 'cy2': ['ap', 'ah', 'cl'], 'ag3': ['ap', 'bh', 'bi'], 'bb3': ['ap', 'bc', 'cj'], 'dd2': ['ap', 'bz', 'dc'], 'cp2': ['aj', 'ag', 'di'], 'ab3': ['ap', 'aq', 'ay'], 'bz1': ['ap', 'ai', 'cq'], 'cf1': ['dk', 'ab', 'ba'], 'ax3': ['bg', 'cz', 'aq'], 'cp3': ['dk', 'bc', 'dd'], 'by3': ['dk', 'cn', 'bv'], 'cf3': ['ap', 'af', 'cg'], 'de3': ['dk', 'br', 'bp'], 'bt1': ['dk', 'ad', 'bf'], 'dg3': ['al', 'bf', 'bl'], 'cm3': ['dk', 'cq', 'cb'], 'bs1': ['aa', 'ag', 'ab'], 'au2': ['aa', 'cf', 'ao'], 'at3': ['ar', 'bh', 'ct'], 'cx1': ['cl', 'cf', 'ay'], 'df1': ['aa', 'cs', 'bu'], 'at2': ['cd', 'ab', 'bd'], 'bw3': ['aa', 'cv', 'cq'], 'bn3': ['aa', 'ai', 'ae'], 'dg1': ['aa', 'bi', 'de'], 'dj3': ['az', 'ad', 'de'], 'cn2': ['az', 'ab', 'bx'], 'be2': ['az', 'bn', 'bs'], 'cq1': ['az', 'ah', 'bx'], 'ci1': ['az', 'da', 'by'], 'di2': ['az', 'cb', 'av'], 'bv2': ['az', 'dc', 'cs'], 'ah3': ['az', 'bt', 'cu'], 'aj3': ['ci', 'dg', 'da'], 'di1': ['ci', 'bs', 'bj'], 'bm2': ['ci', 'by', 'cs'], 'bd3': ['ci', 'cv', 'ca'], 'bo1': ['cx', 'dj', 'ag'], 'cx3': ['ci', 'bp', 'bs'], 'ak2': ['at', 'cs', 'ax'], 'cb3': ['ci', 'ax', 'aq'], 'aq3': ['am', 'bj', 'cl'], 'br3': ['am', 'au', 'ao'], 'dc3': ['am', 'bc', 'bd'], 'cd3': ['am', 'ct', 'ch'], 'ch3': ['am', 'cw', 'bd'], 'cj1': ['am', 'di', 'bj'], 'ay2': ['cd', 'bx', 'ah'], 'cl3': ['cc', 'bt', 'by'], 'cz2': ['cd', 'ag', 'bh'], 'as2': ['cd', 'aq', 'cq'], 'dd3': ['aa', 'bu', 'cr'], 'cn3': ['cd', 'ax', 'db'], 'cd1': ['df', 'ax', 'ck'], 'ck3': ['cd', 'bc', 'bp'], 'cg2': ['dh', 'br', 'bx'], 'ch1': ['dh', 'cr', 'bh'], 'by1': ['dh', 'dd', 'bj'], 'au3': ['cd', 'de', 'bn'], 'ci2': ['dh', 'an', 'cf'], 'bi3': ['dh', 'cz', 'bd'], 'cw1': ['dh', 'ch', 'di'], 'db1': ['dh', 'dc', 'ci'], 'bs2': ['ac', 'ah', 'aq'], 'av3': ['ac', 'ck', 'db'], 'ad3': ['ac', 'ch', 'ce'], 'cm1': ['ac', 'af', 'bc'], 'cv1': ['ar', 'bi', 'cn'], 'ad2': ['ac', 'bp', 'ao'], 'br2': ['ac', 'cl', 'bj'], 'bl2': ['ac', 'al', 'da'], 'bs3': ['bk', 'bz', 'ba'], 'ab2': ['bk', 'bv', 'ai'], 'ch2': ['bk', 'cb', 'ai'], 'af3': ['ak', 'br', 'ao'], 'cn1': ['bk', 'bi', 'de'], 'ca1': ['bk', 'cu', 'bm'], 'bo3': ['bk', 'ae', 'bl'], 'by2': ['bb', 'av', 'cp'], 'ae3': ['bb', 'cp', 'ba'], 'dh3': ['bb', 'an', 'bn'], 'db3': ['bb', 'cn', 'am'], 'bj1': ['bb', 'ch', 'cq'], 'ba1': ['bb', 'bl', 'cv'], 'de2': ['bb', 'bv', 'bm'], 'af2': ['be', 'dg', 'ae'], 'bv3': ['bb', 'ai', 'cm'], 'ax2': ['at', 'cz', 'dc'], 'bz2': ['at', 'dj', 'bs'], 'bh1': ['at', 'an', 'bj'], 'cc2': ['bo', 'ck', 'cp'], 'bk2': ['df', 'bp', 'cj'], 'bj3': ['aa', 'bh', 'de'], 'bg3': ['bw', 'an', 'af'], 'bp3': ['ci', 'cs', 'bx'], 'am3': ['at', 'ai', 'aq'], 'dk2': ['ar', 'cv', 'ab'], 'bm3': ['ar', 'ck', 'bz'], 'dd1': ['ac', 'dk', 'dg'], 'br1': ['ar', 'cb', 'by'], 'aj2': ['ar', 'dd', 'av'], 'cg1': ['dl', 'bm', 'cu'], 'cv3': ['ar', 'an', 'db'], 'ca2': ['be', 'bj', 'cz'], 'bw2': ['ak', 'bu', 'ai'], 'df3': ['ak', 'cu', 'ad'], 'da3': ['cd', 'bs', 'cp'], 'ar2': ['ak', 'br', 'cz'], 'aq2': ['ak', 'cz', 'an'], 'cs2': ['cy', 'ad', 'bh'], 'db2': ['ak', 'cv', 'au'], 'bt2': ['cc', 'af', 'cw'], 'ci3': ['ak', 'dd', 'bl'], 'ck2': ['bo', 'cw', 'aq'], 'bn2': ['as', 'db', 'bl'], 'c ...
# {'aa': ['bs1', 'au2', 'df1', 'bw3', 'bn3', 'dg1', 'dd3', 'bj3', 'bi2'],
#  'ab': ['cf1', 'bs1', 'at2', 'cn2', 'dk2', 'bi1', 'ai2', 'cu1'],
#  'ac': ['bs2', 'av3', 'ad3', 'cm1', 'ad2', 'br2', 'bl2', 'dd1'],
#  'ad': ['bt1', 'dj3', 'df3', 'cs2', 'ct1', 'cr2', 'bd2', 'cq2'],
#  'ae': ['bd1', 'bn3', 'bo3', 'af2', 'bc2', 'bc3', 'am2', 'bu1'],
#  'af': ['cb2', 'cj2', 'cf3', 'cm1', 'bg3', 'bt2', 'ae2', 'al3'],
#  'ag': ['cp2', 'bs1', 'bo1', 'cz2', 'ap2', 'cl2', 'ai2', 'cu3'],
#  'ah': ['cs3', 'cy2', 'cq1', 'ay2', 'bs2', 'dg2', 'al3', 'an2'],
#  'ai': ['ac3', 'bz1', 'bn3', 'ab2', 'ch2', 'bv3', 'am3', 'bw2'],
#  'aj': ['cp2', 'dc2', 'cq3', 'ae2', 'bw1', 'ap2', 'bz3', 'ao3'],
#  'ak': ['af3', 'bw2', 'df3', 'ar2', 'aq2', 'db2', 'ci3', 'bd2'],
#  'al': ['bf1', 'be1', 'bv1', 'bh2', 'cj3', 'bd1', 'dg3', 'bl2', 'ca3'],
#  'am': ['aq3', 'br3', 'dc3', 'cd3', 'ch3', 'cj1', 'db3', 'bq2', 'ao2'],
#  'an': ['ci2', 'dh3', 'bh1', 'bg3', 'cv3', 'aq2', 'bx2', 'dh2'],
#  'ao': ['bn1', 'bv1', 'au2', 'br3', 'ad2', 'af3', 'cr3', 'bo2'],
#  'ap': ['cy2', 'ag3', 'bb3', 'dd2', 'ab3', 'bz1', 'cf3', 'cl2', 'dj2'],
#  'aq': ['cj3', 'ab3', 'ax3', 'cb3', 'as2', 'bs2', 'am3', 'ck2'],
#  'ar': ['at3', 'cv1', 'dk2', 'bm3', 'br1', 'aj2', 'cv3', 'bg2'],
#  'as': ['bn2', 'cm2', 'cx2', 'dk1', 'dh2', 'bq1', 'bp1', 'cq2'],
#  'at': ['bb1', 'ak2', 'ax2', 'bz2', 'bh1', 'am3', 'ce3', 'bh3'],
#  'au': ['dk3', 'cr1', 'br3', 'db2', 'bg1', 'bg2', 'ck1', 'bc1'],
#  'av': ['cw2', 'bf1', 'di2', 'by2', 'aj2', 'cl2', 'cf2', 'bk3'],
#  'aw': ['bi2', 'bu3', 'cd2', 'cu3', 'cu1', 'am2', 'ap3', 'dl1'],
#  'ax': ['ak2', 'cb3', 'cn3', 'cd1', 'ce3', 'cb1', 'az2', 'cl1'],
#  'ay': ['bh2', 'ab3', 'cx1', 'bt3', 'bh3', 'bp2', 'cd2', 'cu1'],
#  'az': ['bd1', 'dj3', 'cn2', 'be2', 'cq1', 'ci1', 'di2', 'bv2', 'ah3'],
#  'ba': ['ay3', 'cf1', 'bs3', 'ae3', 'dc2', 'cs1', 'be3', 'bf3'],
#  'bb': ['by2', 'ae3', 'dh3', 'db3', 'bj1', 'ba1', 'de2', 'bv3'],
#  'bc': ['bb3', 'cp3', 'dc3', 'ck3', 'cm1', 'cw3', 'cp1', 'bx3'],
#  'bd': ['co2', 'at2', 'dc3', 'ch3', 'bi3', 'bl3', 'bq2', 'az3'],
#  'be': ['dk3', 'de1', 'ay3', 'cy1', 'cw2', 'bq3', 'af2', 'ca2', 'dg2'],
#  'bf': ['dh1', 'bt1', 'dg3', 'bl1', 'cx2', 'cq3', 'bi1', 'cc1'],
#  'bg': ['ax3', 'aw2', 'dj1', 'bk1', 'dl3', 'cf2', 'bu2', 'al3'],
#  'bh': ['cs3', 'cc3', 'ag3', 'at3', 'cz2', 'ch1', 'bj3', 'cs2'],
#  'bi': ['ak3', 'ag3', 'dg1', 'cv1', 'cn1', 'dc1', 'bz3', 'ba3'],
#  'bj': ['di1', 'aq3', 'cj1', 'by1', 'br2', 'bh1', 'ca2', 'bu2'],
#  'bk': ['bj2', 'bs3', 'ab2', 'ch2', 'cn1', 'ca1', 'bo3', 'bu1'],
#  'bl': ['be1', 'dg3', 'bo3', 'ba1', 'ci3', 'bn2', 'ca3', 'bz3'],
#  'bm': ['dh1', 'ca1', 'de2', 'cg1', 'bp1', 'ae2', 'dl3', 'ar3'],
#  'bn': ['an3', 'cb2', 'bx1', 'bb1', 'be2', 'au3', 'dh3', 'cg3'],
#  'bo': ['cc2', 'ck2', 'dg2', 'bt3', 'ac2', 'as3', 'cr2', 'ba3'],
#  'bp': ['bx1', 'bv1', 'de3', 'cx3', 'ck3', 'ad2', 'bk2', 'as3'],
#  'bq': ['cb1', 'ct1', 'cz3', 'bg1', 'az2', 'cs1', 'bc3', 'bi1'],
#  'br': ['bq3', 'de3', 'cg2', 'af3', 'ar2', 'ac2', 'da2', 'cy3'],
#  'bs': ['bb1', 'be2', 'di1', 'cx3', 'bz2', 'da3', 'bq1', 'bw1'],
#  'bt': ['ah3', 'cl3', 'ca3', 'ap2', 'bl3', 'cp1', 'ba2', 'ct3'],
#  'bu': ['de1', 'ah2', 'df1', 'dd3', 'bw2', 'bx2', 'da1', 'bc1'],
#  'bv': ['cy1', 'ct2', 'bf1', 'by3', 'ab2', 'de2', 'cz3', 'cc1'],
#  'bw': ['cs3', 'bg3', 'bl3', 'co1', 'cw3', 'dc1', 'aa3', 'az3'],
#  'bx': ['cn2', 'cq1', 'ay2', 'cg2', 'bp3', 'ce1', 'bp1', 'am2'],
#  'by': ['ci1', 'bm2', 'cl3', 'br1', 'ce3', 'cm2', 'as3', 'cd2'],
#  'bz': ['ak3', 'dd2', 'bs3', 'bm3', 'bt3', 'cm2', 'bu1', 'dl2'],
#  'ca': ['ah2', 'be1', 'bd3', 'cq3', 'dc1', 'bc3', 'cu3', 'ai3'],
#  'cb': ['av2', 'cz1', 'cm3', 'di2', 'ch2', 'br1', 'bg1', 'bk1'],
#  'cc': ['cl3', 'bt2', 'ba2', 'bx3', 'an2', 'ct3', 'dj2', 'bf3'],
#  'cd': ['at2', 'ay2', 'cz2', 'as2', 'cn3', 'ck3', 'au3', 'da3', 'df2'],
#  'ce': ['an3', 'co3', 'cb2', 'co2', 'bx1', 'ac3', 'dh1', 'av2', 'ad3'],
#  'cf': ['cr1', 'au2', 'cx1', 'ci2', 'ai2', 'al2', 'dl2', 'bo2'],
#  'cg': ['co3', 'ay3', 'cf3', 'cr2', 'ao2', 'ag2', 'ct3', 'bu3'],
#  'ch': ['cd3', 'cw1', 'ad3', 'bj1', 'bh3', 'bq2', 'ao2', 'ba2'],
#  'ci': ['aj3', 'di1', 'bm2', 'bd3', 'cx3', 'cb3', 'db1', 'bp3', 'ai3'],
#  'cj': ['bq3', 'cv2', 'bb3', 'bk2', 'bb2', 'df2', 'dj2', 'dl1'],
#  'ck': ['co3', 'aw3', 'cd1', 'av3', 'cc2', 'bm3', 'di3', 'an2'],
#  'cl': ['cy2', 'cx1', 'aq3', 'br2', 'bc2', 'bp2', 'ap3', 'bg2'],
#  'cm': ['ct2', 'bv3', 'dk1', 'ac2', 'cu2', 'bk3', 'da1', 'cy3'],
#  'cn': ['cz1', 'by3', 'cv1', 'db3', 'bb2', 'bm1', 'da2', 'ck1'],
#  'co': ['bc2', 'bx2', 'ce1', 'di3', 'aa2', 'bl1', 'bb2', 'df2'],
#  'cp': ['by2', 'ae3', 'cc2', 'da3', 'co1', 'cz3', 'dj1', 'bk1'],
#  'cq': ['bz1', 'cm3', 'bw3', 'as2', 'bj1', 'di3', 'dc2', 'ai3'],
#  'cr': ['aw3', 'bn1', 'dd3', 'ch1', 'dh2', 'dl3', 'bu2', 'bi2'],
#  'cs': ['df1', 'bv2', 'bm2', 'ak2', 'bp3', 'ct1', 'bf3', 'bf2'],
#  'ct': ['de1', 'cv2', 'at3', 'cd3', 'dk1', 'bq1', 'bf2', 'ar3'],
#  'cu': ['cw2', 'cj2', 'ah3', 'ca1', 'cg1', 'df3', 'co1', 'bd2'],
#  'cv': ['bw3', 'bd3', 'ba1', 'dk2', 'db2', 'bl1', 'cf2', 'bu3'],
#  'cw': ['an3', 'ch3', 'bt2', 'ck2', 'ce1', 'aa2', 'az3', 'ce2'],
#  'cx': ['ah2', 'bo1', 'da2', 'al2', 'ar3', 'da1', 'ck1', 'cy3'],
#  'cy': ['aw3', 'ct2', 'cv2', 'bj2', 'cc3', 'cj2', 'bn1', 'cz1', 'cs2'],
#  'cz': ['ax3', 'bi3', 'ax2', 'ca2', 'ar2', 'aq2', 'bw1', 'cg3'],
#  'da': ['ci1', 'aj3', 'bl2', 'cb1', 'bm1', 'ce2', 'dl2', 'bo2'],
#  'db': ['ac3', 'cn3', 'av3', 'cv3', 'bn2', 'aa2', 'aa3', 'ba3'],
#  'dc': ['dk3', 'cy1', 'dd2', 'bv2', 'db1', 'ax2', 'az2', 'dj1'],
#  'dd': ['cp3', 'by1', 'aj2', 'ci3', 'cw3', 'aa3', 'aw2', 'cu2'],
#  'de': ['dg1', 'dj3', 'au3', 'cn1', 'bj3', 'be3', 'bx3', 'cl1'],
#  'df': ['cd1', 'bk2', 'ce2', 'cg3', 'cc1', 'bf2', 'cl1', 'bc1'],
#  'dg': ['co2', 'av2', 'cc3', 'aj3', 'af2', 'dd1', 'cx2', 'cq2'],
#  'dh': ['cg2', 'ch1', 'by1', 'ci2', 'bi3', 'cw1', 'db1', 'bk3', 'dl1'],
#  'di': ['bh2', 'cj3', 'cp2', 'cj1', 'cw1', 'cr3', 'ao3', 'ap3'],
#  'dj': ['bj2', 'bo1', 'bz2', 'cs1', 'aw2', 'ag2', 'ao3', 'al2'],
#  'dk': ['ak3', 'cr1', 'cf1', 'cp3', 'by3', 'de3', 'bt1', 'cm3', 'dd1'],
#  'dl': ['cg1', 'cp1', 'be3', 'ag2', 'bp2', 'cr3', 'cu2', 'bm1']}

# %%
peer_assignment(bigGroups,3)
# Out:
# 9
# 90
# 244
# 12
# {'aa2': ['cc', 'ai', 'cs'],
#  'aa3': ['ao', 'ab', 'bk'],
#  'ab2': ['bg', 'bu', 'ci'],
#  'ab3': ['co', 'dh', 'bi'],
#  'ac2': ['df', 'bl', 'cj'],
#  'ac3': ['ao', 'de', 'au'],
#  'ad2': ['bb', 'cb', 'cn'],
#  'ad3': ['co', 'cb', 'by'],
#  'ae2': ['cf', 'dj', 'cj'],
#  'ae3': ['bf', 'cb', 'ay'],
#  'af2': ['ad', 'bv', 'ak'],
#  'af3': ['ad', 'aj', 'cn'],
#  'ag2': ['ah', 'bp', 'bc'],
#  'ag3': ['cc', 'ab', 'ac'],
#  'ah2': ['dl', 'bn', 'dg'],
#  'ah3': ['ao', 'ae', 'bs'],
#  'ai2': ['bd', 'cx', 'cu'],
#  'ai3': ['aw', 'ba', 'bl'],
#  'aj2': ['dc', 'cp', 'cj'],
#  'aj3': ['bv', 'cm', 'cr'],
#  'ak2': ['df', 'dh', 'az'],
#  'ak3': ['bv', 'cu', 'dd'],
#  'al2': ['bv', 'az', 'ch'],
#  'al3': ['ca', 'az', 'au'],
#  'am2': ['bo', 'bh', 'de'],
#  'am3': ['aw', 'bu', 'aa'],
#  'an2': ['bo', 'bg', 'af'],
#  'an3': ['bz', 'bm', 'cz'],
#  'ao2': ['dl', 'al', 'ae'],
#  'ao3': ['ad', 'cz', 'da'],
#  'ap2': ['ax', 'ch', 'av'],
#  'ap3': ['cf', 'ba', 'be'],
#  'aq2': ['bd', 'bl', 'bt'],
#  'aq3': ['cc', 'bu', 'ak'],
#  'ar2': ['bo', 'by', 'bq'],
#  'ar3': ['aq', 'cl', 'ay'],
#  'as2': ['dc', 'aa', 'au'],
#  'as3': ['db', 'bt', 'bn'],
#  'at2': ['bd', 'ck', 'br'],
#  'at3': ['co', 'bs', 'az'],
#  'au2': ['ap', 'cy', 'cd'],
#  'au3': ['ah', 'cp', 'bs'],
#  'av2': ['bg', 'cs', 'ci'],
#  'av3': ['bz', 'al', 'af'],
#  'aw2': ['bw', 'cv', 'bu'],
#  'aw3': ['dj', 'ba', 'da'],
#  'ax2': ['ca', 'bx', 'ct'],
#  'ax3': ['ad', 'cl', 'ag'],
#  'ay2': ['aq', 'dd', 'av'],
#  'ay3': ['an', 'bh', 'be'],
#  'az2': ['at', 'di', 'cm'],
#  'az3': ['as', 'dk', 'bx'],
#  'ba1': ['an', 'da', 'bc'],
#  'ba2': ['an', 'cn', 'bj'],
#  'ba3': ['bg', 'dd', 'cn'],
#  'bb1': ['cg', 'cq', 'ac'],
#  'bb2': ['as', 'dj', 'al'],
#  'bb3': ['at', 'bi', 'br'],
#  'bc1': ['bg', 'br', 'bt'],
#  'bc2': ['ax', 'bh', 'cd'],
#  'bc3': ['at', 'bt', 'dd'],
#  'bd1': ['aw', 'cn', 'cy'],
#  'bd2': ['db', 'aa', 'cr'],
#  'bd3': ['bz', 'bk', 'dg'],
#  'be1': ['cf', 'aa', 'bu'],
#  'be2': ['ar', 'ba', 'by'],
#  'be3': ['am', 'ab', 'bj'],
#  'bf1': ['bb', 'al', 'bl'],
#  'bf2': ['bv', 'ce', 'ae'],
#  'bf3': ['ao', 'cx', 'cq'],
#  'bg1': ['bf', 'br', 'de'],
#  'bg2': ['cw', 'dl', 'au'],
#  'bg3': ['am', 'bn', 'ct'],
#  'bh1': ['bf', 'br', 'af'],
#  'bh2': ['bb', 'cy', 'di'],
#  'bh3': ['ar', 'cs', 'az'],
#  'bi1': ['ca', 'bs', 'ci'],
#  'bi2': ['dc', 'ay', 'cf'],
#  'bi3': ['bz', 'bc', 'bo'],
#  'bj1': ['bf', 'dk', 'ba'],
#  'bj2': ['aw', 'cq', 'ct'],
#  'bj3': ['df', 'ac', 'bi'],
#  'bk1': ['df', 'cv', 'cr'],
#  'bk2': ['bw', 'bp', 'dk'],
#  'bk3': ['am', 'cd', 'ct'],
#  'bl1': ['ao', 'bm', 'ai'],
#  'bl2': ['db', 'cy', 'cp'],
#  'bl3': ['ax', 'dk', 'ae'],
#  'bm1': ['bo', 'bl', 'ba'],
#  'bm2': ['as', 'bp', 'bj'],
#  'bm3': ['bw', 'cr', 'dg'],
#  'bn1': ['bd', 'dj', 'dh'],
#  'bn2': ['bz', 'ch', 'bi'],
#  'bn3': ['bz', 'ct', 'ab'],
#  'bo1': ['ah', 'br', 'bi'],
#  'bo2': ['ah', 'dd', 'cx'],
#  'bo3': ['dc', 'cz', 'ac'],
#  'bp1': ['cw', 'bj', 'bx'],
#  'bp2': ['cc', 'dg', 'ac'],
#  'bp3': ['aq', 'ce', 'bk'],
#  'bq1': ['an', 'cq', 'cx'],
#  'bq2': ['bv', 'cp', 'cm'],
#  'bq3': ['bo', 'cb', 'be'],
#  'br1': ['ar', 'dh', 'cy'],
#  'br2': ['co', 'bl', 'cy'],
#  'br3': ['ao', 'av', 'bz'],
#  'bs1': ['ad', 'da', 'ak'],
#  'bs2': ['bw', 'bi', 'bx'],
#  'bs3': ['bv', 'bu', 'da'],
#  'bt1': ['df', 'bl', 'af'],
#  'bt2': ['as', 'cn', 'dh'],
#  'bt3': ['db', 'ba', 'ci'],
#  'bu1': ['as', 'be', 'ak'],
#  'bu2': ['cc', 'cj', 'cx'],
#  'bu3': ['ar', 'au', 'cd'],
#  'bv1': ['at', 'dc', 'bs'],
#  'bv2': ['dl', 'by', 'cx'],
#  'bv3': ['an', 'bk', 'ai'],
#  'bw1': ['db', 'av', 'al'],
#  'bw2': ['dl', 'br', 'dh'],
#  'bw3': ['bo', 'be', 'ct'],
#  'bx1': ['db', 'cj', 'bp'],
#  'bx2': ['dc', 'ce', 'ci'],
#  'bx3': ['bb', 'cs', 'av'],
#  'by1': ['cf', 'af', 'ch'],
#  'by2': ['bv', 'da', 'cv'],
#  'by3': ['dl', 'bk', 'bx'],
#  'bz1': ['bo', 'di', 'ag'],
#  'bz2': ['aq', 'bs', 'ag'],
#  'bz3': ['dj', 'au', 'ck'],
#  'ca1': ['bb', 'dk', 'bq'],
#  'ca2': ['co', 'dh', 'cj'],
#  'ca3': ['am', 'ck', 'ct'],
#  'cb1': ['aw', 'ai', 'bq'],
#  'cb2': ['co', 'aj', 'ay'],
#  'cb3': ['bd', 'cz', 'dd'],
#  'cc1': ['ax', 'bk', 'ae'],
#  'cc2': ['aw', 'ay', 'bm'],
#  'cc3': ['df', 'cd', 'dh'],
#  'cd1': ['bf', 'af', 'cu'],
#  'cd2': ['ca', 'ay', 'bq'],
#  'cd3': ['am', 'bq', 'bt'],
#  'ce1': ['bv', 'cm', 'cu'],
#  'ce2': ['ad', 'au', 'dg'],
#  'ce3': ['ah', 'bh', 'cl'],
#  'cf1': ['ca', 'cp', 'aj'],
#  'cf2': ['ca', 'bc', 'aj'],
#  'cf3': ['da', 'dj', 'ch'],
#  'cg1': ['aw', 'cs', 'cp'],
#  'cg2': ['dl', 'bn', 'cy'],
#  'cg3': ['df', 'de', 'al'],
#  'ch1': ['cg', 'bp', 'cb'],
#  'ch2': ['bg', 'ce', 'cd'],
#  'ch3': ['ar', 'av', 'cv'],
#  'ci1': ['bz', 'dj', 'dk'],
#  'ci2': ['ar', 'cy', 'bq'],
#  'ci3': ['cc', 'cq', 'ce'],
#  'cj1': ['cw', 'ai', 'dj'],
#  'cj2': ['ax', 'bx', 'bh'],
#  'cj3': ['db', 'cr', 'bs'],
#  'ck1': ['bw', 'ba', 'aj'],
#  'ck2': ['ah', 'ca', 'de'],
#  'ck3': ['ar', 'cl', 'ci'],
#  'cl1': ['dc', 'cz', 'bc'],
#  'cl2': ['am', 'cv', 'ac'],
#  'cl3': ['ca', 'bk', 'af'],
#  'cm1': ['ad', 'cl', 'br'],
#  'cm2': ['cg', 'ag', 'bt'],
#  'cm3': ['db', 'aa', 'al'],
#  'cn1': ['bg', 'by', 'bh'],
#  'cn2': ['bf', 'aj', 'bm'],
#  'cn3': ['bg', 'ak', 'ag'],
#  'co1': ['at', 'dk', 'ce'],
#  'co2': ['bb', 'ag', 'ak'],
#  'co3': ['df', 'ck', 'ay'],
#  'cp1': ['at', 'ab', 'bp'],
#  'cp2': ['an', 'ah', 'bm'],
#  'cp3': ['am', 'cr', 'dk'],
#  'cq1': ['aq', 'cv', 'bj'],
#  'cq2': ['cf', 'aj', 'bm'],
#  'cq3': ['bd', 'ab', 'dg'],
#  'cr1': ['ap', 'bn', 'cd'],
#  'cr2': ['dc', 'ct', 'bk'],
#  'cr3': ['ap', 'cs', 'ce'],
#  'cs1': ['aq', 'bp', 'bq'],
#  'cs2': ['cg', 'ag', 'bx'],
#  'cs3': ['ax', 'bs', 'ab'],
#  'ct1': ['at', 'cz', 'bt'],
#  'ct2': ['bf', 'di', 'cj'],
#  'ct3': ['at', 'ac', 'df'],
#  'cu1': ['cg', 'bt', 'da'],
#  'cu2': ['ah', 'af', 'cz'],
#  'cu3': ['an', 'cn', 'de'],
#  'cv1': ['dc', 'bi', 'ae'],
#  'cv2': ['ax', 'bq', 'bn'],
#  'cv3': ['cc', 'bc', 'ak'],
#  'cw1': ['aq', 'ch', 'cl'],
#  'cw2': ['ao', 'cp', 'di'],
#  'cw3': ['bz', 'cr', 'ay'],
#  'cx1': ['aq', 'az', 'cl'],
#  'cx2': ['bw', 'bh', 'aq'],
#  'cx3': ['bd', 'ae', 'al'],
#  'cy1': ['cw', 'aa', 'bn'],
#  'cy2': ['cw', 'cu', 'cm'],
#  'cy3': ['cw', 'bm', 'ai'],
#  'cz1': ['co', 'av', 'cb'],
#  'cz2': ['cf', 'ck', 'di'],
#  'cz3': ['as', 'ck', 'cu'],
#  'da1': ['ap', 'aj', 'ck'],
#  'da2': ['cg', 'ae', 'az'],
#  'da3': ['ar', 'av', 'cw'],
#  'db1': ['bw', 'bx', 'cq'],
#  'db2': ['as', 'bn', 'bl'],
#  'db3': ['as', 'bh', 'bj'],
#  'dc1': ['cg', 'di', 'de'],
#  'dc2': ['ca', 'cv', 'bu'],
#  'dc3': ['ad', 'bj', 'ce'],
#  'dd1': ['ap', 'ci', 'au'],
#  'dd2': ['ax', 'bm', 'bi'],
#  'dd3': ['ao', 'ai', 'bc'],
#  'de1': ['cg', 'cz', 'cs'],
#  'de2': ['dl', 'ck', 'cb'],
#  'de3': ['cf', 'by', 'bc'],
#  'df1': ['aw', 'be', 'bj'],
#  'df2': ['bf', 'cv', 'dd'],
#  'df3': ['am', 'ac', 'cm'],
#  'dg1': ['bo', 'cp', 'di'],
#  'dg2': ['cw', 'bu', 'bp'],
#  'dg3': ['bb', 'be', 'cb'],
#  'dh1': ['co', 'cs', 'cq'],
#  'dh2': ['an', 'cx', 'cj'],
#  'dh3': ['bw', 'by', 'cl'],
#  'di1': ['ap', 'dg', 'aa'],
#  'di2': ['dl', 'cn', 'be'],
#  'di3': ['ah', 'cm', 'ai'],
#  'dj1': ['ap', 'az', 'dg'],
#  'dj2': ['ci', 'ak', 'cx'],
#  'dj3': ['cf', 'dd', 'ag'],
#  'dk1': ['bd', 'cm', 'ab'],
#  'dk2': ['cc', 'aa', 'cu'],
#  'dk3': ['bb', 'cu', 'cd'],
#  'dl1': ['ap', 'ch', 'cr'],
#  'dl2': ['bg', 'by', 'cq'],
#  'dl3': ['cw', 'ch', 'de']}
